# %%
import numpy as np
import pandas as pd
import os
import shutil

# %%
stock = pd.read_csv("data/stock data top 100 tech company 2019_11_1.csv")

# %%
stock
# Out:
#    Symbol                                Name Price (Intraday)  Change  \
# 0    AAPL                          Apple Inc.           255.82    7.06
# 1    MSFT               Microsoft Corporation           143.72    0.35
# 2    GOOG                       Alphabet Inc.         1,273.74   13.63
# 3   GOOGL                       Alphabet Inc.         1,272.25   13.45
# 4      FB                      Facebook, Inc.           193.62    1.97
# ..    ...                                 ...              ...     ...
# 95   LYFT                          Lyft, Inc.            42.98    1.54
# 96   PAGS              PagSeguro Digital Ltd.            37.17    0.09
# 97   PAYC               Paycom Software, Inc.           214.31    2.78
# 98    TDY  Teledyne Technologies Incorporated           336.15    6.55
# 99   LDOS               Leidos Holdings, Inc.            85.33   -0.90
#
#    % Change   Volume Avg Vol (3 month) Market Cap PE Ratio (TTM)  \
# ...

# %%
type(stock)
# Out:
# pandas.core.frame.DataFrame

# %%
Name_list = list(stock['Symbol'])
Name_list
# Out:
# ['AAPL',
#  'MSFT',
#  'GOOG',
#  'GOOGL',
#  'FB',
#  'TSM',
#  'INTC',
#  'CSCO',
#  'ORCL',
#  'SAP',
#  'CRM',
#  'ADBE',
#  'NVDA',
#  'IBM',
#  'ACN',
#  'AVGO',
#  'ASML',
#  'TXN',
#  'QCOM',
#  'SNE',
#  'INTU',
#  'VMW',
#  'MU',
#  'UBER',
#  'AMAT',
#  'NOW',
#  'ATVI',
#  'INFY',
#  'ADI',
#  'LRCX',
#  'AMD',
#  'DELL',
#  'WDAY',
#  'NTES',
#  'SHOP',
#  'BIDU',
#  'CTSH',
#  'ADSK',
#  'NXPI',
#  'TEL',
#  'APH',
#  'TEAM',
#  'ERIC',
#  'EA',
#  'MSI',
#  'KLAC',
#  'SQ',
#  'HPQ',
#  'SPOT',
#  'FLT',
#  'FTV-PA',
#  'FTV',
#  'XLNX',
#  'MCHP',
#  'TME',
#  'TWTR',
#  'GLW',
#  'PANW',
#  'VRSN',
#  'HPE',
#  'VEEV',
#  'SNAP',
#  'GIB',
#  'CERN',
#  'STM',
#  'MTCH',
#  'SNPS',
#  'IAC',
#  'KEYS',
#  'SPLK',
#  'CDW',
#  'ANSS',
#  'CDNS',
#  'GRMN',
#  'CHKP',
#  'SWKS',
#  'MRVL',
#  'MXIM',
#  'WDC',
#  'FTNT',
#  'STX',
#  'SSNC',
#  'SYMC',
#  'CTXS',
#  'ANET',
#  'AKAM',
#  'IT',
#  'NTAP',
#  'RNG',
#  'OKTA',
#  'SE',
#  'TTWO',
#  'TWLO',
#  'ZBRA',
# ...
